# %% [markdown]
# <a href="https://colab.research.google.com/github/hantswilliams/HHA_507_2023/blob/main/WK2/inClassExample_wk2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning in Class
#
# This is going to be our examples provided in class where we review will be from [chapter 2](https://book.datascience.appliedhealthinformatics.com/docs/Ch2/pandas)

# %% [markdown]
# ## Load Packages

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/HHA_507_2023/main/WK2/data/Hospital_Cost_Report_2019.csv')
df

# %% [markdown]
# ### Data Interpretation
#
# It appears each row is a unique hospital (business). As a example, Stony Brook, despite have 3 hospitals, only has one row within this dataset

# %% [markdown]
# ## Inspecting Shape

# %%
# Check the size and shape of the DataFrame
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 6118
# Number of columns: 126

# %%
# Now lets check using the size function
print("Using size: ", df.size)
# Out:
# Using size:  770868

# %%
# Lets just use shape
print(" Using shape alone: ", df.shape)
# Out:
#  Using shape alone:  (6118, 126)

# %% [markdown]
# #### Interpretation
#
# My interpretation of this shape is that it is small data, rows ~= 6000, but there are a large number of columns > 100

# %% [markdown]
# ## Previewing Data

# %%
# first 5
df.head(5)
# Out:
#    rpt_rec_num  Provider CCN                        Hospital Name  \
# 0       700569         52043  1125 SIR FRANCIS DRAKE OPERATING CO
# 1       698041        421301        ABBEVILLE AREA MEDICAL CENTER
# 2       709145        190034           ABBEVILLE GENERAL HOSPITAL
# 3       705454        240057         ABBOTT NORTHWESTERN HOSPITAL
# 4       705220        450558                  ABILENE REG MED CTR
#
#                   Street Address         City State Code    Zip Code  \
# 0    1125 SIR FRANCIS DRAKE BLVD    KENTFIELD         CA  94904-1455
# 1  ABBEVILLE AREA MEDICAL CENTER    ABBEVILLE         SC       29620
# 2       118 NORTH HOSPITAL DRIVE    ABBEVILLE         LA  70511-0580
# 3           800 EAST 28TH STREET  MINNEAPOLIS         MN       55407
# 4                 6250 HWY 83/84      ABILENE         TX       79606
#
#       County  Medicare CBSA Number Rural Versus Urban  ...  \
# 0        NaN               94904.0                  U  ...
# ...

# %%
# last 5
df.tail(5)
# Out:
#       rpt_rec_num  Provider CCN                         Hospital Name  \
# 6113       713551         61315                YUMA DISTRICT HOSPITAL
# 6114       707159         30013          YUMA REGIONAL MEDICAL CENTER
# 6115       685609         33034  YUMA REHABILITATION HOSPITAL  AN AFF
# 6116       687770        192041        ZACHARY-AMG SPECIALTY HOSPITAL
# 6117       708981         50228      ZUCKERBERG SAN FRANCISCO GENERAL
#
#                Street Address           City State Code Zip Code  \
# 6113     1000 WEST 8TH AVENUE           YUMA         CO   80759-
# 6114          2400 S AVENUE A           YUMA         AZ    85364
# 6115     901 WEST 24TH STREET           YUMA         AZ    85364
# 6116  4601 MCHUGH RD.  BLDG B        ZACHARY         LA    70791
# 6117      1001 POTRERO AVENUE  SAN FRANCISCO         CA   94110-
#
#                      County  Medicare CBSA Number Rural Versus Urban  ...  \
# 6113                   YUMA               99906.0                  R  ...
# ...

# %%
# random sample 5
df.sample(5)
# Out:
#       rpt_rec_num  Provider CCN                     Hospital Name  \
# 5397       708196        100128            TAMPA GENERAL HOSPITAL
# 1000       682777        321308           CIBOLA GENERAL HOSPITAL
# 1914       712139         61317     GRAND RIVER HOSPITAL DISTRICT
# 5017       701359        360276  ST ELIZABETH BOARDMAN HEALTH CTR
# 1036       711831        521990        CLEARVIEW HOME CORPORATION
#
#               Street Address        City State Code    Zip Code        County  \
# 5397  1 TAMPA GENERAL CIRCLE       TAMPA         FL  33606-3508  HILLSBOROUGH
# 1000          1016 ROOSEVELT      GRANTS         NM       87020        CIBOLA
# 1914        501 AIRPORT ROAD       RIFLE         CO       81650           NaN
# 5017      8401 MARKET STREET  YOUNGSTOWN         OH       44512      MAHONING
# 1036         935 MAIN STREET   DELAFIELD         WI       53018      WAUKESHA
#
#       Medicare CBSA Number Rural Versus Urban  ...  \
# ...

# %%
## lets say we wanted to get 1% sample of the data
onePercentSample = int(df.shape[0] * .01)

df.sample(onePercentSample)

# %%
df.columns
# Out:
# Index(['rpt_rec_num', 'Provider CCN', 'Hospital Name', 'Street Address',
#        'City', 'State Code', 'Zip Code', 'County', 'Medicare CBSA Number',
#        'Rural Versus Urban',
#        ...
#        'Net Income from Service to Patients', 'Total Other Income',
#        'Total Income', 'Total Other Expenses', 'Net Income',
#        'Cost To Charge Ratio', 'Net Revenue from Medicaid', 'Medicaid Charges',
#        'Net Revenue from Stand-Alone SCHIP', 'Stand-Alone SCHIP Charges'],
#       dtype='object', length=126)

# %%
list(df)

# %%
### Preview 2 columns within a new dataframe called netincome

netincome = df[['Hospital Name', 'Net Income', 'Total Other Income', 'Cost To Charge Ratio']]
netincome.head(5)
# Out:
#                          Hospital Name  Net Income  Total Other Income  \
# 0  1125 SIR FRANCIS DRAKE OPERATING CO   4167716.0            282333.0
# 1        ABBEVILLE AREA MEDICAL CENTER   -797432.0           5205543.0
# 2           ABBEVILLE GENERAL HOSPITAL   1796757.0           3694407.0
# 3         ABBOTT NORTHWESTERN HOSPITAL  50563800.0         229952218.0
# 4                  ABILENE REG MED CTR   3386811.0          10527317.0
#
#    Cost To Charge Ratio
# 0                   NaN
# 1              0.525693
# 2              0.308672
# 3              0.268633
# 4              0.100260

# %%
netincome.describe()
# Out:
#          Net Income  Total Other Income  Cost To Charge Ratio
# count  6.013000e+03        5.799000e+03           4691.000000
# mean   1.026506e+07        2.037738e+07              1.031930
# std    7.186361e+07        7.780671e+07             33.677305
# min   -9.800109e+08       -7.710121e+08              0.055417
# 25%   -9.019650e+05        5.647925e+05              0.199217
# 50%    1.577785e+06        2.821260e+06              0.290734
# 75%    1.035629e+07        1.179821e+07              0.473881
# max    2.209102e+09        1.740090e+09           2280.353040

# %%
df['Hospital Name'].value_counts()
# Out:
# ENCOMPASS HEALTH REHABILITATION HOSP    98
# GOOD SAMARITAN HOSPITAL                  9
# MEMORIAL HOSPITAL                        8
# MERCY MEDICAL CENTER                     7
# COMMUNITY MEMORIAL HOSPITAL              7
#                                         ..
# HENRY COUNTY HOSPITAL (CAH)              1
# HENRY COUNTY HEALTH CENTER               1
# HENRICO DOCTORS HOSPITAL                 1
# HENNEPIN COUNTY MEDICAL CENTER           1
# ZUCKERBERG SAN FRANCISCO GENERAL         1
# Name: Hospital Name, Length: 5728, dtype: int64

# %%
encompass_hospital = df[df['Hospital Name'] == 'ENCOMPASS HEALTH REHABILITATION HOSP']
encompass_hospital.groupby(['Hospital Name']).sum()
# Out:
# <ipython-input-37-06dce147605f>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   encompass_hospital.groupby(['Hospital Name']).sum()
#                                       rpt_rec_num  Provider CCN  \
# Hospital Name
# ENCOMPASS HEALTH REHABILITATION HOSP     67072823      31447403
#
#                                       Medicare CBSA Number  Provider Type  \
# Hospital Name
# ENCOMPASS HEALTH REHABILITATION HOSP             3025575.0            347
#
#                                       Type of Control  \
# Hospital Name
# ENCOMPASS HEALTH REHABILITATION HOSP              408
#
#                                       FTE - Employees on Payroll  \
# Hospital Name
# ENCOMPASS HEALTH REHABILITATION HOSP                    15321.27
#
# ...

# %%
df
# Out:
#       rpt_rec_num  Provider CCN                         Hospital Name  \
# 0          700569         52043   1125 SIR FRANCIS DRAKE OPERATING CO
# 1          698041        421301         ABBEVILLE AREA MEDICAL CENTER
# 2          709145        190034            ABBEVILLE GENERAL HOSPITAL
# 3          705454        240057          ABBOTT NORTHWESTERN HOSPITAL
# 4          705220        450558                   ABILENE REG MED CTR
# ...           ...           ...                                   ...
# 6113       713551         61315                YUMA DISTRICT HOSPITAL
# 6114       707159         30013          YUMA REGIONAL MEDICAL CENTER
# 6115       685609         33034  YUMA REHABILITATION HOSPITAL  AN AFF
# 6116       687770        192041        ZACHARY-AMG SPECIALTY HOSPITAL
# 6117       708981         50228      ZUCKERBERG SAN FRANCISCO GENERAL
#
#                      Street Address           City State Code    Zip Code  \
# ...

# %%
df.columns
# Out:
# Index(['rpt_rec_num', 'Provider CCN', 'Hospital Name', 'Street Address',
#        'City', 'State Code', 'Zip Code', 'County', 'Medicare CBSA Number',
#        'Rural Versus Urban',
#        ...
#        'Net Income from Service to Patients', 'Total Other Income',
#        'Total Income', 'Total Other Expenses', 'Net Income',
#        'Cost To Charge Ratio', 'Net Revenue from Medicaid', 'Medicaid Charges',
#        'Net Revenue from Stand-Alone SCHIP', 'Stand-Alone SCHIP Charges'],
#       dtype='object', length=126)

# %%
data = pd.DataFrame({
    'bad Row': [1, 2, 3],
    'another bad row': [3, 2, 1]
})
data
# Out:
#    bad Row  another bad row
# 0        1                3
# 1        2                2
# 2        3                1

# %%
df.dtypes

df['Provider CCN'] = str(df['Provider CCN'])

df.dtypes
# Out:
# rpt_rec_num                             int64
# Provider CCN                           object
# Hospital Name                          object
# Street Address                         object
# City                                   object
#                                        ...
# Cost To Charge Ratio                  float64
# Net Revenue from Medicaid             float64
# Medicaid Charges                      float64
# Net Revenue from Stand-Alone SCHIP    float64
# Stand-Alone SCHIP Charges             float64
# Length: 126, dtype: object

# %%
import pandas as pd
import re

data = pd.DataFrame({
    'Bad Row 1': [1, 2],
    'Bad Row 2': [3, 4]
})

print(data)

# Function to remove white space and special characters from a value
def clean_column(column):
    column = column.str.replace(r'[^a-zA-Z0-9]', '')
    column = column.str.lower()
    return column

# Apply the clean_value function to all columns
for column in data.columns:
    data[column] = data[column].apply(clean_value)

print(data)
# Out:
#    Bad Row 1  Bad Row 2
# 0          1          3
# 1          2          4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-80e84fae37b7> in <cell line: 18>()
#      17 # Apply the clean_value function to all columns
#      18 for column in data.columns:
# ---> 19     data[column] = data[column].apply(clean_value)
#      20
#      21 print(data)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# ...
