# %%
df = read.csv('heartdisease.csv')
df
# Out:
#     X   age sex cp trestbps chol fbs restecg thalach exang oldpeak slope ca
# 1    0  63  1   1  145      233  1   2       150     0     2.3     3     0
# 2    1  67  1   4  160      286  0   2       108     1     1.5     2     3
# 3    2  67  1   4  120      229  0   2       129     1     2.6     2     2
# 4    3  37  1   3  130      250  0   0       187     0     3.5     3     0
# 5    4  41  0   2  130      204  0   2       172     0     1.4     1     0
# 6    5  56  1   2  120      236  0   0       178     0     0.8     1     0
# 7    6  62  0   4  140      268  0   2       160     0     3.6     3     2
# 8    7  57  0   4  120      354  0   0       163     1     0.6     1     0
# 9    8  63  1   4  130      254  0   2       147     0     1.4     2     1
# 10   9  53  1   4  140      203  1   2       155     1     3.1     3     0
# 11  10  57  1   4  140      192  0   0       148     0     0.4     2     0
# ...

# %%
df$cp = as.character(df$cp)
df$exang = as.character(df$exang)

# %%
df
# Out:
#     X   age sex cp trestbps chol fbs restecg thalach exang oldpeak slope ca
# 1    0  63  1   1  145      233  1   2       150     0     2.3     3     0
# 2    1  67  1   4  160      286  0   2       108     1     1.5     2     3
# 3    2  67  1   4  120      229  0   2       129     1     2.6     2     2
# 4    3  37  1   3  130      250  0   0       187     0     3.5     3     0
# 5    4  41  0   2  130      204  0   2       172     0     1.4     1     0
# 6    5  56  1   2  120      236  0   0       178     0     0.8     1     0
# 7    6  62  0   4  140      268  0   2       160     0     3.6     3     2
# 8    7  57  0   4  120      354  0   0       163     1     0.6     1     0
# 9    8  63  1   4  130      254  0   2       147     0     1.4     2     1
# 10   9  53  1   4  140      203  1   2       155     1     3.1     3     0
# 11  10  57  1   4  140      192  0   0       148     0     0.4     2     0
# ...

# %%
model = aov(thalach ~ cp * exang, data=df)
summary(model)
# Out:
#              Df Sum Sq Mean Sq F value   Pr(>F)
# cp            3  23503    7834  18.494 5.08e-11 ***
# exang         1   8190    8190  19.333 1.53e-05 ***
# cp:exang      3   1366     455   1.075     0.36
# Residuals   295 124967     424
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
means <- aggregate(thalach ~ cp, data=df, FUN=mean)
print(means)
# Out:
#   cp  thalach
# 1  1 155.9565
# 2  2 162.4200
# 3  3 155.4070
# 4  4 140.6806

# %%
TukeyHSD(model)
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = thalach ~ cp * exang, data = df)
#
# $cp
#           diff        lwr        upr     p adj
# 2-1   6.463478  -6.934731  19.861687 0.5978117
# 3-1  -0.549545 -13.032987  11.933897 0.9994727
# 4-1 -15.275966 -27.217148  -3.334785 0.0058452
# 3-2  -7.013023 -16.470373   2.444327 0.2235394
# 4-2 -21.739444 -30.468532 -13.010357 0.0000000
# 4-3 -14.726421 -21.973578  -7.479264 0.0000017
#
# $exang
#         diff      lwr       upr     p adj
# 1-0 -9.80335 -14.7648 -4.841901 0.0001246
#
# $`cp:exang`
#                 diff        lwr        upr     p adj
# 2:0-1:0   8.59839817  -8.536813  25.733609 0.7896251
# 3:0-1:0   0.72912281 -15.408702  16.866947 1.0000000
# 4:0-1:0  -7.23108553 -23.646837   9.184665 0.8808260
# 1:1-1:0   1.56578947 -32.999931  36.131510 0.9999999
# 2:1-1:0 -14.68421053 -49.249931  19.881510 0.8995414
# 3:1-1:0  -7.13875598 -30.944183  16.666671 0.9844280
# ...
